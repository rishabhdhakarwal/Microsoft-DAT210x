# %%
import pandas as pd

# %%
df=pd.read_csv("/home/rishabh/Desktop/Data Science/DAT210x-master/Module2/Datasets/servo.data" , names = ['motor', 'screw', 'pgain', 'vgain', 'class'])

# %%
df
# Out:
#     motor screw  pgain  vgain     class
# 0       E     E      5      4  0.281251
# 1       B     D      6      5  0.506252
# 2       D     D      4      3  0.356251
# 3       B     A      3      2  5.500033
# 4       D     B      6      5  0.356251
# 5       E     C      4      3  0.806255
# 6       C     A      3      2  5.100014
# 7       A     A      3      2  5.700042
# 8       C     A      6      5  0.768754
# 9       D     A      4      1  1.031254
# 10      B     E      6      5  0.468752
# 11      E     C      5      4  0.393752
# 12      B     C      4      1  0.281251
# 13      E     C      3      1  1.100000
# 14      C     C      5      4  0.506252
# 15      E     B      3      2  1.899990
# 16      D     C      3      1  0.900001
# 17      B     C      5      4  0.468752
# 18      B     B      5      4  0.543753
# 19      C     E      4      2  0.206250
# 20      E     D      4      3  0.918755
# 21      A     D      4      3  1.106248
# ...

# %%
slice1 = df[df.vgain == 5]
print slice1
print len(slice1)
# Out:
#     motor screw  pgain  vgain     class
# 1       B     D      6      5  0.506252
# 4       D     B      6      5  0.356251
# 8       C     A      6      5  0.768754
# 10      B     E      6      5  0.468752
# 22      B     C      6      5  0.468752
# 24      A     B      6      5  0.581253
# 25      E     C      6      5  0.393752
# 34      C     C      6      5  0.506252
# 38      C     B      6      5  0.543753
# 50      D     A      6      5  0.431252
# 70      B     A      6      5  0.806255
# 73      A     E      6      5  0.506252
# 81      A     C      6      5  0.506252
# 84      E     A      6      5  0.581253
# 95      A     D      6      5  0.506252
# 108     E     B      6      5  0.431252
# 112     C     D      6      5  0.468752
# 117     E     D      6      5  0.318751
# 132     E     E      6      5  0.281251
# 135     B     B      6      5  0.543753
# 161     C     E      6      5  0.468752
# 166     A     A      6      5  0.806255
# 22

# %%
slice2 = df[(df.motor == 'E') & (df.screw == 'E')]
print slice2
print len(slice2)
# Out:
#     motor screw  pgain  vgain     class
# 0       E     E      5      4  0.281251
# 35      E     E      3      2  1.100000
# 86      E     E      4      3  0.843755
# 132     E     E      6      5  0.281251
# 140     E     E      4      2  0.506252
# 151     E     E      3      1  0.700001
# 6

# %%
slice3 = df[df.pgain == 4]
print slice3.mean()
# Out:
# pgain    4.000000
# vgain    2.060606
# class    0.673298
# dtype: float64

# %%
print df.dtypes
# Out:
# motor     object
# screw     object
# pgain      int64
# vgain      int64
# class    float64
# dtype: object
